# %% [markdown]
# #### **0 Imports**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from statsmodels.tsa.arima_model import ARMA
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller, kpss, acf, pacf
from statsmodels.stats.diagnostic import acorr_ljungbox, het_arch, het_breuschpagan
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
from arch import arch_model
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
import pylab
from statsmodels.api import qqplot
import statsmodels.api as sm
from statsmodels.tsa.ar_model import AutoReg
import scipy.stats as stats
warnings.filterwarnings('ignore')

# %%
def plot_acf_and_pacf(serie, nlags=30):
    lag_acf = acf(serie, nlags=nlags)
    lag_pacf = pacf(serie, nlags = nlags, method='ols')
    
    #Plot ACF
    plt.rcParams["figure.figsize"] = (15,8)
    plt.subplot(121) 
    plt.plot(lag_acf)
    plt.axhline(y=0,linestyle='--',color='gray')
    plt.axhline(y=-1.96/np.sqrt(len(serie)),linestyle='--',color='gray')
    plt.axhline(y=1.96/np.sqrt(len(serie)),linestyle='--',color='gray')
    plt.title('Autocorrelation Function')
    
    
    #Plot PACF
    plt.subplot(122)
    plt.plot(lag_pacf)
    plt.axhline(y=0,linestyle='--',color='gray')
    plt.axhline(y=-1.96/np.sqrt(len(serie)),linestyle='--',color='gray')
    plt.axhline(y=1.96/np.sqrt(len(serie)),linestyle='--',color='gray') 
    plt.title('Partial Autocorrelation Function') 
    plt.tight_layout()

# %%
##pd.set_option('display.float_format', lambda x: '%.2f' % x)
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'ggplot')
    plt.rcParams['figure.figsize'] = [13, 6]
    plt.rcParams['font.size'] = 20
    
    #display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    
jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### **1.0 Load Data and Treatment**

# %%
data = pd.read_excel('./data/exchange_rate.xlsx')
data.shape
# Out:
# (7009, 2)

# %%
data.head(15)
# Out:
#    JBDCBRL Index  PX_LAST
# 0     1994-01-04    81.93
# 1     1994-01-05    82.30
# 2     1994-01-06    82.65
# 3     1994-01-07    82.78
# 4     1994-01-10    84.58
# 5     1994-01-11    86.21
# 6     1994-01-12    86.18
# 7     1994-01-13    85.00
# 8     1994-01-14    84.98
# 9     1994-01-18    88.56
# 10    1994-01-19    88.34
# 11    1994-01-20    87.98
# 12    1994-01-21    87.81
# 13    1994-01-24    88.72
# 14    1994-01-25    90.87

# %% [markdown]
# ###### **1.2 Rename columns and rows**

# %%
data = data.rename({'JBDCBRL Index': 'date', 'PX_LAST': 'value'}, axis=1)

# %% [markdown]
# ###### **1.3 Data types**

# %%
data.dtypes
# Out:
# date     datetime64[ns]
# value           float64
# dtype: object

# %% [markdown]
# ###### **1.4 Check NaN**

# %%
data.isna().sum()
# Out:
# date     0
# value    0
# dtype: int64

# %% [markdown]
# ###### **1.5 Numerical Analysis**

# %%
num_attributes = data.select_dtypes(include=['float'])

# %%
# Central tendency - mean, median
#mean
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
#median
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

#Dispersion - desvio, minimo, maximo, range, skew, kutosi

d1 = pd.DataFrame(num_attributes.apply(np.std)).T

d2 = pd.DataFrame(num_attributes.apply(np.min)).T

d3 = pd.DataFrame(num_attributes.apply(np.max)).T

d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T

d5 = pd.DataFrame(num_attributes.apply(lambda x : x.skew())).T

d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

#concat 
h = pd.concat([d2,d3,d4,ct1,ct2,d1,d5,d6]).T.reset_index()
h.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']

# %%
h
# Out:
#   attributes    min     max  range       mean  median        std      skew  kurtosis
# 0      value  42.43  109.69  67.26  79.923703   79.85  16.617289 -0.073575 -1.051584

# %% [markdown]
# #### **2.0 Data Visualization e Testes**

# %%
df2 = data.copy()
#df2 = df2.loc[(df2['date'] > '2008-01-01') & (df2['date'] < '2021-12-31')]
df2.head(10)
# Out:
#         date  value
# 0 1994-01-04  81.93
# 1 1994-01-05  82.30
# 2 1994-01-06  82.65
# 3 1994-01-07  82.78
# 4 1994-01-10  84.58
# 5 1994-01-11  86.21
# 6 1994-01-12  86.18
# 7 1994-01-13  85.00
# 8 1994-01-14  84.98
# 9 1994-01-18  88.56

# %%
sns.lineplot(x = 'date', y='value', data=df2)
plt.title('JBDCBRL Index')
plt.ylabel('Price')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
df2 = df2.loc[(df2['date'] > '2008-01-01') & (df2['date'] < '2021-12-31')]
sns.lineplot(x = 'date', y='value', data=df2)
plt.title('JBDCBRL Index')
plt.ylabel('Price')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
plot_acf(df2['value'], lags=60)

# %% [markdown]
# ###### **2.1 ADF Test - In nivel**

# %%
def adf_test(timeseries):
    print("Results of Dickey-Fuller Test:")
    dftest = adfuller(timeseries, autolag="AIC")
    dfoutput = pd.Series(
        dftest[0:4],
        index=[
            "Test Statistic",
            "p-value",
            "#Lags Used",
            "Number of Observations Used",
        ],
    )
    for key, value in dftest[4].items():
        dfoutput["Critical Value (%s)" % key] = value
    print(dfoutput)

# %%
adf_test(df2['value'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.744153
# p-value                           0.834979
# #Lags Used                        5.000000
# Number of Observations Used    3509.000000
# Critical Value (1%)              -3.432215
# Critical Value (5%)              -2.862364
# Critical Value (10%)             -2.567209
# dtype: float64

# %% [markdown]
# ###### **2.2 KPSS - In nivel**

# %%
def kpss_test(timeseries):
    print("Results of KPSS Test:")
    kpsstest = kpss(timeseries, regression="c", nlags="auto")
    kpss_output = pd.Series(
        kpsstest[0:3], index=["Test Statistic", "p-value", "Lags Used"]
    )
    for key, value in kpsstest[3].items():
        kpss_output["Critical Value (%s)" % key] = value
    print(kpss_output)

# %%
kpss_test(df2['value'])
# Out:
# Results of KPSS Test:
# Test Statistic            7.038882
# p-value                   0.010000
# Lags Used                37.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64

# %% [markdown]
# #### **3.0 Retorno e modelagem**

# %%
df3 = df2.copy()

# %%
#Retornos
df3['retornos'] = df3['value'].pct_change(periods=1).fillna(0)
df3['retornos_quadrados'] = df3['retornos'] ** 2


#Plot series in 1° diff
sns.lineplot(x = 'date', y='retornos', data=df3)
# sns.lineplot(x = 'date', y='zero', data=df3)

plt.title('Retorno do índice JBDCBRL Index')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
#Retornos ao quadrado
sns.lineplot(x = 'date', y='retornos_quadrados', data=df3)
# sns.lineplot(x = 'date', y='zero', data=df3)

plt.title('Retornos quadrados do índice JBDCBRL Index')
plt.xlabel('Data')
plt.ylabel('Retornos ao quadrado')
# Out:
# Text(0, 0.5, 'Retornos ao quadrado')

# %% [markdown]
# ##### **3.1 Testes dos retornos**

# %%
df4 = df3.dropna()

# %%
adf_test(df4['retornos'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -26.291440
# p-value                           0.000000
# #Lags Used                        5.000000
# Number of Observations Used    3509.000000
# Critical Value (1%)              -3.432215
# Critical Value (5%)              -2.862364
# Critical Value (10%)             -2.567209
# dtype: float64

# %%
kpss_test(df4['retornos'])
# Out:
# Results of KPSS Test:
# Test Statistic            0.099219
# p-value                   0.100000
# Lags Used                20.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64

# %%
plot_acf_and_pacf(df4['retornos'])

# %%
plot_acf_and_pacf(df4['retornos'] ** 2)

# %%
acorr_ljungbox(df3['retornos'], lags=[30], return_df = True)
# Out:
#       lb_stat  lb_pvalue
# 30  63.089587   0.000383

# %% [markdown]
# ##### 3.2 Modelagem de volatilidade

# %%
#Série estacionária
adfuller(df3['retornos'])
# Out:
# (-26.291439516041173,
#  0.0,
#  5,
#  3509,
#  {'1%': -3.4322149444714065,
#   '5%': -2.8623640267493293,
#   '10%': -2.567208643634359},
#  -22513.48740666268)

# %% [markdown]
# ##### 3.2.1 ARMA(1,1)

# %%
model_11 = SARIMAX(df3['retornos'], order=(1,0,1))
model_results_11 = model_11.fit()
model_results_11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               retornos   No. Observations:                 3515
# Model:               SARIMAX(1, 0, 1)   Log Likelihood               11368.789
# Date:                Thu, 16 Jun 2022   AIC                         -22731.578
# Time:                        13:56:07   BIC                         -22713.084
# Sample:                             0   HQIC                        -22724.979
#                                - 3515
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3824      0.127     -3.001      0.003      -0.632      -0.133
# ma.L1          0.3357      0.131      2.571      0.010       0.080       0.592
# sigma2      9.082e-05   9.35e-07     97.116      0.000     8.9e-05    9.27e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             19117.79
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                             0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ##### 3.2.2 ARMA(2,2)

# %%
model = SARIMAX(df3['retornos'], order=(2,0,2))
model_results = model.fit()
model_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               retornos   No. Observations:                 3515
# Model:               SARIMAX(2, 0, 2)   Log Likelihood               11370.197
# Date:                Thu, 16 Jun 2022   AIC                         -22730.395
# Time:                        13:56:09   BIC                         -22699.571
# Sample:                             0   HQIC                        -22719.396
#                                - 3515
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0847      0.282     -0.301      0.764      -0.637       0.467
# ar.L2          0.4397      0.134      3.285      0.001       0.177       0.702
# ma.L1          0.0319      0.282      0.113      0.910      -0.521       0.585
# ma.L2         -0.4490      0.140     -3.200      0.001      -0.724      -0.174
# sigma2      9.066e-05    9.6e-07     94.427      0.000    8.88e-05    9.25e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):             18352.32
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                             0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ##### 3.2.3 ARMA(3,3)

# %%
model_arma_33 = SARIMAX(df3['retornos'], order=(3,0,3))
model_results_arma_33 = model_arma_33.fit()
model_results_arma_33.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               retornos   No. Observations:                 3515
# Model:               SARIMAX(3, 0, 3)   Log Likelihood               11373.512
# Date:                Thu, 16 Jun 2022   AIC                         -22733.024
# Time:                        13:56:10   BIC                         -22689.871
# Sample:                             0   HQIC                        -22717.627
#                                - 3515
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9571      0.135      7.069      0.000       0.692       1.222
# ar.L2         -0.0115      0.216     -0.053      0.958      -0.435       0.412
# ar.L3         -0.4782      0.127     -3.777      0.000      -0.726      -0.230
# ma.L1         -1.0055      0.141     -7.144      0.000      -1.281      -0.730
# ma.L2          0.0739      0.229      0.323      0.746      -0.374       0.522
# ma.L3          0.4278      0.134      3.184      0.001       0.164       0.691
# sigma2       9.05e-05   9.53e-07     94.991      0.000    8.86e-05    9.24e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             17774.87
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                             0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ###### 3.3.4 Testes nos resíduos do modelo ARMA(3,3)

# %%
arma_residuals = model_results_arma_33.resid
plot_acf_and_pacf(arma_residuals)

# %%
acorr_ljungbox(arma_residuals, return_df = True, lags=[30])
# Out:
#       lb_stat  lb_pvalue
# 30  42.822748   0.060737

# %%
#Teste de heterocedasticidade
het_arch(arma_residuals)
# Out:
# (750.6837346491234,
#  8.189088352288032e-155,
#  95.22831498545804,
#  1.1280273747742438e-174)

# %% [markdown]
# #### 4.0 Volatilidade

# %% [markdown]
# ##### 4.1 GARCH(1,1): Distribuição normal

# %%
resid_model_11 = arch_model(arma_residuals, p=1, q=1, vol='GARCH') 
resid_model_results_11 = resid_model_11.fit(update_freq=5)
resid_model_results_11.summary()
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -11917.52332900111
#             Iterations: 6
#             Function evaluations: 18
#             Gradient evaluations: 2
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                11917.5
# Distribution:                  Normal   AIC:                          -23827.0
# Method:            Maximum Likelihood   BIC:                          -23802.4
#                                         No. Observations:                 3515
# Date:                Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                        13:56:11   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -1.5363e-05  1.465e-04     -0.105      0.917 [-3.026e-04,2.719e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.8113e-06  1.993e-13  9.090e+06      0.000 [1.811e-06,1.811e-06]
# alpha[1]       0.1000  1.660e-04    602.466      0.000   [9.967e-02,  0.100]
# beta[1]        0.8800  5.884e-03    149.547      0.000     [  0.868,  0.892]
# ============================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ##### 4.1 GARCH(2,1): Distribuição normal

# %%
resid_model_21 = arch_model(arma_residuals, p=2, q=1, vol='GARCH') 
resid_model_results = resid_model_21.fit(update_freq=5)
resid_model_results.summary()
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -11914.237602129902
#             Iterations: 6
#             Function evaluations: 20
#             Gradient evaluations: 2
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                11914.2
# Distribution:                  Normal   AIC:                          -23818.5
# Method:            Maximum Likelihood   BIC:                          -23787.7
#                                         No. Observations:                 3515
# Date:                Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                        13:56:11   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -3.2899e-05  1.472e-04     -0.224      0.823 [-3.213e-04,2.555e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.8113e-06  9.692e-14  1.869e+07      0.000 [1.811e-06,1.811e-06]
# alpha[1]       0.0500  2.034e-03     24.588 1.718e-133 [4.601e-02,5.399e-02]
# alpha[2]       0.0500  1.480e-02      3.379  7.285e-04 [2.099e-02,7.901e-02]
# beta[1]        0.8800  1.407e-02     62.540      0.000     [  0.852,  0.908]
# ============================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ##### 4.1 GARCH(1,2): : Distribuição normal

# %%
resid_model = arch_model(arma_residuals, p=1, q=2, vol='GARCH') 
resid_model_results = resid_model.fit(update_freq=5)
resid_model_results.summary()
# Out:
# Iteration:      5,   Func. Count:     67,   Neg. LLF: 6.98744353983959e+25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -11909.26036810828
#             Iterations: 12
#             Function evaluations: 112
#             Gradient evaluations: 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                11909.3
# Distribution:                  Normal   AIC:                          -23808.5
# Method:            Maximum Likelihood   BIC:                          -23777.7
#                                         No. Observations:                 3515
# Date:                Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                        13:56:11   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -9.8868e-06  2.328e-05     -0.425      0.671 [-5.552e-05,3.575e-05]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.8113e-06  8.328e-12  2.175e+05      0.000 [1.811e-06,1.811e-06]
# alpha[1]       0.1000  1.077e-02      9.283  1.648e-20   [7.889e-02,  0.121]
# beta[1]        0.4400      0.113      3.895  9.817e-05     [  0.219,  0.661]
# beta[2]        0.4400      0.114      3.853  1.164e-04     [  0.216,  0.664]
# ============================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ##### 4.1 GARCH(1,1): : Distribuição t-Student

# %%
resid_model_11_tstudent = arch_model(arma_residuals, p=1, q=1, vol='GARCH', dist='t') 
resid_model_results_11 = resid_model_11_tstudent.fit(update_freq=5)
resid_model_results_11.summary()
# Out:
# Iteration:      5,   Func. Count:     48,   Neg. LLF: 6594.358712223014
# Iteration:     10,   Func. Count:     94,   Neg. LLF: 31653.596011433903
# Iteration:     15,   Func. Count:    141,   Neg. LLF: 61777.44096531042
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 61777.44096531042
#             Iterations: 20
#             Function evaluations: 146
#             Gradient evaluations: 16
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         None   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -61777.4
# Distribution:      Standardized Student's t   AIC:                           123565.
# Method:                  Maximum Likelihood   BIC:                           123596.
#                                               No. Observations:                 3515
# Date:                      Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                              13:56:11   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu           495.4606      0.151   3283.983      0.000 [4.952e+02,4.958e+02]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      9.0565e-04  9.419e-04      0.961      0.336 [-9.405e-04,2.752e-03]
# alpha[1]       1.0000  9.709e-03    103.001      0.000      [  0.981,  1.019]
# beta[1]        0.0000  1.845e-02      0.000      1.000 [-3.616e-02,3.616e-02]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             2.3094  6.484e-04   3561.674      0.000 [  2.308,  2.311]
# ========================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ##### 4.1 GARCH(2,1): : Distribuição t-Student

# %%
resid_model_21_tstudent = arch_model(arma_residuals, p=2, q=1, vol='GARCH', dist='t') 
resid_model_results_21 = resid_model_21_tstudent.fit(update_freq=5)
resid_model_results_21.summary()
# Out:
# Iteration:      5,   Func. Count:     62,   Neg. LLF: -2440.936190725777
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -153.4342926725083
#             Iterations: 13
#             Function evaluations: 111
#             Gradient evaluations: 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         None   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:                153.434
# Distribution:      Standardized Student's t   AIC:                          -294.869
# Method:                  Maximum Likelihood   BIC:                          -257.880
#                                               No. Observations:                 3515
# Date:                      Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                              13:56:11   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu            -0.2260  4.617e-03    -48.956      0.000 [ -0.235, -0.217]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.6931e-04  1.801e-04      0.940      0.347 [-1.836e-04,5.222e-04]
# alpha[1]       0.4200      0.369      1.139      0.255      [ -0.303,  1.143]
# alpha[2]       0.0352      1.931  1.823e-02      0.985      [ -3.750,  3.820]
# beta[1]        0.5408      2.341      0.231      0.817      [ -4.047,  5.129]
#                                Distribution
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# nu           143.0689     44.238      3.234  1.220e-03 [ 56.364,2.298e+02]
# ==========================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ##### 4.1 GARCH(1,2): : Distribuição t-Student

# %%
resid_model_12_tstudent =  arch_model(arma_residuals, p=1, q=2,  vol='GARCH', dist='t') 
resid_model_results_12 = resid_model_12_tstudent.fit(update_freq=5)
resid_model_results_12.summary()
# Out:
# Iteration:      5,   Func. Count:     60,   Neg. LLF: 272495.3498159847
# Iteration:     10,   Func. Count:    123,   Neg. LLF: 1708.2820218382033
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 758147.4247711052
#             Iterations: 16
#             Function evaluations: 172
#             Gradient evaluations: 14
# C:\Users\victo\Music\Projetos\Python\tcc\venv\lib\site-packages\arch\univariate\base.py:753: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         None   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -758147.
# Distribution:      Standardized Student's t   AIC:                       1.51631e+06
# Method:                  Maximum Likelihood   BIC:                       1.51634e+06
#                                               No. Observations:                 3515
# Date:                      Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                              13:56:11   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu         4.2845e+04    491.056     87.251      0.000 [4.188e+04,4.381e+04]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      4.5170e-04  4.948e-04      0.913      0.361 [-5.182e-04,1.422e-03]
# alpha[1]       0.9276  5.226e-03    177.503      0.000      [  0.917,  0.938]
# beta[1]        0.2768  3.290e-02      8.414  3.967e-17      [  0.212,  0.341]
# beta[2]    1.7813e-03  8.231e-03      0.216      0.829 [-1.435e-02,1.791e-02]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu            30.2958      0.355     85.277      0.000 [ 29.599, 30.992]
# ========================================================================
#
# Covariance estimator: robust
# WARNING: The optimizer did not indicate successful convergence. The message was Inequality constraints incompatible.
# See convergence_flag.
#
# """

# %% [markdown]
# ##### 4.1 GARCH(1,1): Distribuição t-Student skewed

# %%
resid_model_11 = arch_model(arma_residuals, p=1, q=1, vol='GARCH', dist='skewt') 
resid_model_results_11 = resid_model_11.fit(update_freq=5)
resid_model_results_11.summary()
# Out:
# Iteration:      5,   Func. Count:     56,   Neg. LLF: 797411.8310235988
# Iteration:     10,   Func. Count:    118,   Neg. LLF: 7872.730813693919
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7872.730795389241
#             Iterations: 14
#             Function evaluations: 118
#             Gradient evaluations: 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Constant Mean - GARCH Model Results
# =========================================================================================
# Dep. Variable:                              None   R-squared:                       0.000
# Mean Model:                        Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                                 GARCH   Log-Likelihood:               -7872.73
# Distribution:      Standardized Skew Student's t   AIC:                           15757.5
# Method:                       Maximum Likelihood   BIC:                           15794.5
#                                                    No. Observations:                 3515
# Date:                           Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                                   13:56:12   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu            -1.8200  9.763e-03   -186.415      0.000 [ -1.839, -1.801]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      4.1840e-04  3.875e-04      1.080      0.280 [-3.412e-04,1.178e-03]
# alpha[1]       0.6014      0.333      1.808  7.064e-02   [-5.062e-02,  1.253]
# beta[1]        0.3902      0.330      1.181      0.238      [ -0.257,  1.038]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# eta           22.4853      3.160      7.116  1.113e-12 [ 16.292, 28.679]
# lambda         0.3759  3.134e-03    119.943      0.000 [  0.370,  0.382]
# ========================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ##### 4.1 GARCH(2,1): Distribuição t-Student skewed

# %%
resid_model_21 = arch_model(arma_residuals, p=2, q=1, vol='GARCH', dist='skewt') 
resid_model_results_21 = resid_model_21.fit(update_freq=5)
resid_model_results_21.summary()
# Out:
# Iteration:      5,   Func. Count:     57,   Neg. LLF: 12730.318708217475
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 1213721.4464560421
#             Iterations: 9
#             Function evaluations: 92
#             Gradient evaluations: 8
# C:\Users\victo\Music\Projetos\Python\tcc\venv\lib\site-packages\arch\univariate\base.py:753: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Constant Mean - GARCH Model Results
# =========================================================================================
# Dep. Variable:                              None   R-squared:                       0.000
# Mean Model:                        Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                                 GARCH   Log-Likelihood:           -1.21372e+06
# Distribution:      Standardized Skew Student's t   AIC:                       2.42746e+06
# Method:                       Maximum Likelihood   BIC:                       2.42750e+06
#                                                    No. Observations:                 3515
# Date:                           Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                                   13:56:12   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu         2.3835e+06  4.423e+04     53.884      0.000 [2.297e+06,2.470e+06]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      4.1101e-04  4.481e-04      0.917      0.359 [-4.672e-04,1.289e-03]
# alpha[1]       0.2531      0.228      1.112      0.266      [ -0.193,  0.699]
# alpha[2]       0.0289      0.228      0.127      0.899      [ -0.417,  0.475]
# beta[1]        0.7129      1.000      0.713      0.476      [ -1.246,  2.672]
#                                Distribution
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# eta           30.5425      0.588     51.944      0.000   [ 29.390, 31.695]
# lambda         0.0815  1.262e-02      6.456  1.075e-10 [5.673e-02,  0.106]
# ==========================================================================
#
# Covariance estimator: robust
# WARNING: The optimizer did not indicate successful convergence. The message was Inequality constraints incompatible.
# See convergence_flag.
#
# """

# %% [markdown]
# ##### 4.1 GARCH(1,2): Distribuição t-Student skewed

# %%
resid_model_12 = arch_model(arma_residuals, p=1, q=2, vol='GARCH', dist='skewt') 
resid_model_results_12 = resid_model_12.fit(update_freq=5)
resid_model_results_12.summary()
# Out:
# Iteration:      5,   Func. Count:     62,   Neg. LLF: 816037.4720741254
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11019.823919937331
#             Iterations: 9
#             Function evaluations: 88
#             Gradient evaluations: 7
# C:\Users\victo\Music\Projetos\Python\tcc\venv\lib\site-packages\arch\univariate\base.py:753: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Constant Mean - GARCH Model Results
# =========================================================================================
# Dep. Variable:                              None   R-squared:                       0.000
# Mean Model:                        Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                                 GARCH   Log-Likelihood:                11019.8
# Distribution:      Standardized Skew Student's t   AIC:                          -22025.6
# Method:                       Maximum Likelihood   BIC:                          -21982.5
#                                                    No. Observations:                 3515
# Date:                           Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                                   13:56:12   Df Model:                            1
#                                    Mean Model
# ===============================================================================
#                   coef    std err          t      P>|t|        95.0% Conf. Int.
# -------------------------------------------------------------------------------
# mu         -1.5420e-03  3.479e-04     -4.433  9.296e-06 [-2.224e-03,-8.602e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      9.1297e-07  2.609e-08     34.992 3.009e-268 [8.618e-07,9.641e-07]
# alpha[1]       0.6022  6.003e-02     10.032  1.108e-23     [  0.485,  0.720]
# beta[1]        0.1764  1.445e-02     12.204  2.977e-34     [  0.148,  0.205]
# beta[2]        0.1764  1.455e-02     12.121  8.190e-34     [  0.148,  0.205]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# eta           19.7234      5.012      3.935  8.305e-05 [  9.901, 29.546]
# lambda        -0.2104  1.758e-02    -11.969  5.153e-33 [ -0.245, -0.176]
# ========================================================================
#
# Covariance estimator: robust
# WARNING: The optimizer did not indicate successful convergence. The message was Inequality constraints incompatible.
# See convergence_flag.
#
# """

# %% [markdown]
# ##### 4.1 GARCH(2,2): Distribuição normal

# %%
resid_model_12 = arch_model(arma_residuals, p=2, q=2, vol='GARCH') 
resid_model_results_12 = resid_model_12.fit(update_freq=5)
resid_model_results_12.summary()
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -11909.650680998962
#             Iterations: 6
#             Function evaluations: 22
#             Gradient evaluations: 2
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                11909.7
# Distribution:                  Normal   AIC:                          -23807.3
# Method:            Maximum Likelihood   BIC:                          -23770.3
#                                         No. Observations:                 3515
# Date:                Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                        13:56:12   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -2.3480e-05  9.745e-05     -0.241      0.810 [-2.145e-04,1.675e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.8113e-06  9.644e-13  1.878e+06      0.000 [1.811e-06,1.811e-06]
# alpha[1]       0.0500  2.358e-02      2.120  3.398e-02 [3.782e-03,9.622e-02]
# alpha[2]       0.0500  5.617e-02      0.890      0.373  [-6.009e-02,  0.160]
# beta[1]        0.4400      0.779      0.565      0.572     [ -1.086,  1.966]
# beta[2]        0.4400      0.746      0.590      0.555     [ -1.022,  1.902]
# ============================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ##### 4.2 Teste nos resíduos do modelo GARCH(1,1)

# %%
resid_model_11 = arch_model(arma_residuals, p=1, q=1, vol='GARCH') 
resid_model_results_11 = resid_model_11.fit(update_freq=5)
resid_model_results_11.summary()
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -11917.52332900111
#             Iterations: 6
#             Function evaluations: 18
#             Gradient evaluations: 2
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                11917.5
# Distribution:                  Normal   AIC:                          -23827.0
# Method:            Maximum Likelihood   BIC:                          -23802.4
#                                         No. Observations:                 3515
# Date:                Thu, Jun 16 2022   Df Residuals:                     3514
# Time:                        13:56:12   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -1.5363e-05  1.465e-04     -0.105      0.917 [-3.026e-04,2.719e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.8113e-06  1.993e-13  9.090e+06      0.000 [1.811e-06,1.811e-06]
# alpha[1]       0.1000  1.660e-04    602.466      0.000   [9.967e-02,  0.100]
# beta[1]        0.8800  5.884e-03    149.547      0.000     [  0.868,  0.892]
# ============================================================================
#
# Covariance estimator: robust
# """

# %%
residuos_garch = resid_model_results_11.resid
conditional_volatility = resid_model_results_11.conditional_volatility

# %%
std_resid = residuos_garch / conditional_volatility
unit_var_resid = residuos_garch / residuos_garch.std()
df = pd.concat([std_resid, unit_var_resid], 1)
df.columns = ["Resíduos padronizados", "Resíduos de Variância Unitária"]
subplot = df.plot(kind="kde", xlim=(-4, 4))

# %%
acorr_ljungbox(residuos_garch, return_df = True, lags=[20])
# Out:
#       lb_stat  lb_pvalue
# 20  15.405895    0.75273

# %%
#Resíduos GARCH
plot_acf_and_pacf(residuos_garch, 60)

# %%
#Resíduos quadrados padronizados
plot_acf_and_pacf(std_resid ** 2, 60)

# %%
acorr_ljungbox(std_resid, lags=[30])
# Out:
#       lb_stat  lb_pvalue
# 30  29.865634   0.472551

# %%
print(f'O teste ARCH-LM apresentou uma estatística-F de {het_arch(std_resid)[2]}')
print(f'O teste ARCH-LM apresentou uma valor-p de {het_arch(std_resid)[3]}')
# Out:
# O teste ARCH-LM apresentou uma estatística-F de 0.13329081610256274
# O teste ARCH-LM apresentou uma valor-p de 0.999365689661178

# %% [markdown]
# ##### 4.3 Volatilidade estimada

# %%
fig = resid_model_results_11.plot()
